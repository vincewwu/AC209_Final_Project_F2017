# %% [markdown]
# # CS 109A/STAT 121A/AC 209A/CSCI E-109A:
# # Final Project - 2017
#
# **Harvard University**<br/>
# **Fall 2017**<br/>
# **Instructors**: Pavlos Protopapas, Kevin Rader, Rahul Dave, Margo Levine<br/>
# **Leading TF**: Albert Wu<br/>
# **Project Group #**: 16 (Sports)
#
# ---

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import IFrame, HTML
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.basketball-reference.com/boxscores/pbp/201612010GSW.html'

# %%
game_pd_raw = pd.read_html(url, header=1)[0]
game_pd_raw
# Out:
#         Time                                            Houston  Unnamed: 2  \
# 0    12:00.0                               Start of 1st quarter         NaN
# 1    12:00.0  Jump ball: C. Capela vs. Z. Pachulia (R. Ander...         NaN
# 2    11:38.0                 T. Ariza makes 2-pt shot from 1 ft         2.0
# 3    11:13.0                                                NaN         NaN
# 4    11:01.0                C. Capela makes 2-pt shot from 3 ft         2.0
# 5    10:48.0                                                NaN         NaN
# 6    10:26.0  R. Anderson misses 2-pt shot from 3 ft (block ...         NaN
# 7    10:25.0                   Offensive rebound by R. Anderson         NaN
# 8    10:23.0              R. Anderson makes 2-pt shot from 1 ft         2.0
# 9    10:15.0                                                NaN         NaN
# 10   10:15.0                          Defensive rebound by Team         NaN
# 11   10:15.0                                                NaN         NaN
# 12   10:05.0                J. Harden makes 2-pt shot from 3 ft         2.0
# 13    9:52.0                                                NaN         NaN
# 14    9:52.0                     Defensive rebound by J. Harden         NaN
# 15    9:43.0  R. Anderson makes 3-pt shot from 26 ft (assist...         3.0
# 16    9:33.0   Personal foul by P. Beverley (drawn by S. Curry)         NaN
# 17    9:30.0                                                NaN         NaN
# 18    9:30.0                                                NaN         NaN
# 19    9:17.0  J. Harden makes 2-pt shot at rim (assist by T....         2.0
# 20    9:16.0                                                NaN         NaN
# 21    9:16.0                                                NaN         NaN
# 22    9:00.0                                                NaN         NaN
# 23    8:55.0  J. Harden misses 2-pt shot from 3 ft (block by...         NaN
# 24    8:54.0                                                NaN         NaN
# 25    8:50.0                                                NaN         NaN
# 26    8:33.0            P. Beverley misses 3-pt shot from 26 ft         NaN
# 27    8:33.0                                                NaN         NaN
# 28    8:25.0                                                NaN         NaN
# 29    8:12.0  Turnover by J. Harden (bad pass; steal by K. D...         NaN
# ..       ...                                                ...         ...
# 594   0:53.0              J. Harden misses 3-pt shot from 26 ft         NaN
# 595   0:52.0                    Offensive rebound by M. Harrell         NaN
# 596   0:27.0              J. Harden misses 3-pt shot from 27 ft         NaN
# 597   0:26.0                    Offensive rebound by M. Harrell         NaN
# 598   0:26.0                 M. Harrell misses 2-pt shot at rim         NaN
# 599   0:26.0                                                NaN         NaN
# 600   0:26.0                                                NaN         NaN
# 601   0:26.0        P. Beverley enters the game for R. Anderson         NaN
# 602   0:26.0                                                NaN         NaN
# 603   0:21.0                                                NaN         NaN
# 604   0:21.0                                                NaN         NaN
# 605   0:20.0                                                NaN         NaN
# 606   0:20.0                                                NaN         NaN
# 607   0:20.0                                                NaN         NaN
# 608   0:20.0         R. Anderson enters the game for M. Harrell         NaN
# 609   0:20.0                                                NaN         NaN
# 610   0:16.0                                                NaN         NaN
# 611   0:16.0                               Houston full timeout         NaN
# 612   0:08.0                                                NaN         NaN
# 613   0:08.0                   T. Ariza makes free throw 1 of 2         1.0
# 614   0:08.0                   T. Ariza makes free throw 2 of 2         1.0
# 615   0:08.0                                                NaN         NaN
# 616   0:08.0                                                NaN         NaN
# 617   0:08.0                                                NaN         NaN
# 618   0:08.0         M. Harrell enters the game for R. Anderson         NaN
# 619   0:06.0                                                NaN         NaN
# 620   0:03.0                                                NaN         NaN
# 621   0:02.0                                                NaN         NaN
# 622   0:01.0                     Defensive rebound by J. Harden         NaN
# 623   0:00.0                                End of 2nd overtime         NaN
#
#        Score  Unnamed: 4                                       Golden State
# 0        NaN         NaN                                                NaN
# 1        NaN         NaN                                                NaN
# 2        2-0         NaN                                                NaN
# 3        2-2         2.0  K. Durant makes 2-pt shot at rim (assist by Z....
# 4        4-2         NaN                                                NaN
# 5        4-4         2.0  S. Curry makes 2-pt shot from 12 ft (assist by...
# 6        4-4         NaN                                                NaN
# 7        4-4         NaN                                                NaN
# 8        6-4         NaN                                                NaN
# 9        6-4         NaN  Z. Pachulia misses 2-pt shot from 2 ft (block ...
# 10       6-4         NaN                                                NaN
# 11       6-4         NaN  Loose ball foul by Z. Pachulia (drawn by P. Be...
# 12       8-4         NaN                                                NaN
# 13       8-4         NaN              K. Durant misses 3-pt shot from 24 ft
# 14       8-4         NaN                                                NaN
# 15      11-4         NaN                                                NaN
# 16      11-4         NaN                                                NaN
# 17      11-4         NaN                      Offensive foul by Z. Pachulia
# 18      11-4         NaN           Turnover by Z. Pachulia (offensive foul)
# 19      13-4         NaN                                                NaN
# 20      13-4         NaN                          Golden State full timeout
# 21      13-4         NaN        A. Iguodala enters the game for Z. Pachulia
# 22      13-4         NaN  Turnover by D. Green (bad pass; steal by T. Ar...
# 23      13-4         NaN                                                NaN
# 24      13-4         NaN                      Defensive rebound by S. Curry
# 25      13-6         2.0  A. Iguodala makes 2-pt shot at rim (assist by ...
# 26      13-6         NaN                                                NaN
# 27      13-6         NaN                      Defensive rebound by D. Green
# 28      13-6         NaN                Turnover by K. Thompson (traveling)
# 29      13-6         NaN                                                NaN
# ..       ...         ...                                                ...
# 594  130-124         NaN                                                NaN
# 595  130-124         NaN                                                NaN
# 596  130-124         NaN                                                NaN
# 597  130-124         NaN                                                NaN
# 598  130-124         NaN                                                NaN
# 599  130-124         NaN                      Defensive rebound by D. Green
# 600  130-124         NaN                          Golden State full timeout
# 601  130-124         NaN                                                NaN
# 602  130-124         NaN         I. Clark enters the game for S. Livingston
# 603  130-124         NaN            K. Thompson misses 3-pt shot from 25 ft
# 604  130-124         NaN                      Offensive rebound by D. Green
# 605  130-126         2.0                 D. Green makes 2-pt shot from 2 ft
# 606  130-126         NaN    Shooting foul by M. Harrell (drawn by D. Green)
# 607  130-127         1.0                   D. Green makes free throw 1 of 1
# 608  130-126         NaN                                                NaN
# 609  130-126         NaN         S. Livingston enters the game for I. Clark
# 610  130-127         NaN  Personal take foul by K. Durant (drawn by P. B...
# 611  130-127         NaN                                                NaN
# 612  130-127         NaN      Personal foul by D. Green (drawn by T. Ariza)
# 613  131-127         NaN                                                NaN
# 614  132-127         NaN                                                NaN
# 615  132-127         NaN                          Golden State full timeout
# 616  130-127         NaN             K. Looney enters the game for D. Green
# 617  132-127         NaN             I. Clark enters the game for K. Looney
# 618  132-127         NaN                                                NaN
# 619  132-127         NaN            K. Thompson misses 3-pt shot from 26 ft
# 620  132-127         NaN                      Offensive rebound by I. Clark
# 621  132-127         NaN               I. Clark misses 2-pt shot from 16 ft
# 622  132-127         NaN                                                NaN
# 623      NaN         NaN                                                NaN
#
# [624 rows x 6 columns]

# %%
game_pd = game_pd_raw.copy()

away_team = game_pd.columns[1]
home_team = game_pd.columns[5]
game_pd.columns = ['time', 'away_events','away_pts','score','home_pts','home_events']
game_pd['away_team'] = away_team
game_pd['home_team'] = home_team

events = game_pd['home_events']
events = events.fillna(game_pd['away_events'])
game_pd['events'] = events
game_pd['is_home_event'] = 1 - pd.isnull(game_pd['home_events'])

game_pd['score'] = game_pd['score'].replace(to_replace='Score',method='ffill')
game_pd['score'] = game_pd['score'].fillna(method='backfill')
game_pd = game_pd.drop(game_pd.index[game_pd['score'].isnull()], axis=0)

score_str = game_pd['score'].str.split('-').tolist()
away_score,home_score = np.transpose(np.array(score_str))
away_score = away_score.astype(int)
home_score = home_score.astype(int)
game_pd['away_score'] = away_score
game_pd['home_score'] = home_score
game_pd['score_diff'] = home_score - away_score

game_pd = game_pd.drop(['away_events', 'away_pts', 'score', 'home_pts', 'home_events'], axis=1)

game_pd['t_elapsed'] = game_pd['time'].str.split(':')
quarter_str = ['2nd Q', '3rd Q', '4th Q', '1st OT', '2nd OT', '3rd OT', '4th OT']
last_ind = 0
for i in range(len(quarter_str)):
    if any(game_pd['time'].str.contains(quarter_str[i])):
        ind_Q = game_pd.index[game_pd['time'].str.contains(quarter_str[i])][0]
        game_pd = game_pd.drop(np.arange(ind_Q-1, ind_Q+3, 1).tolist(), axis=0)
        game_pd.loc[last_ind:ind_Q, 't_elapsed'] = game_pd.loc[last_ind:ind_Q, 't_elapsed'].apply(
            lambda s: 720*np.min([4, i+1]) + 300*np.max([0, i-2]) - (float(s[0])*60+float(s[1])))
        last_ind = ind_Q
    else:
        game_pd.loc[last_ind:, 't_elapsed'] = game_pd.loc[last_ind:, 't_elapsed'].apply(
            lambda s: 720*4 + 300*np.max([0, i-3]) - (float(s[0])*60+float(s[1])))
        break

game_pd = game_pd.drop(0, axis=0).reset_index(drop=True)

game_pd.head()
# Out:
#       time away_team     home_team  \
# 0  12:00.0   Houston  Golden State
# 1  11:38.0   Houston  Golden State
# 2  11:13.0   Houston  Golden State
# 3  11:01.0   Houston  Golden State
# 4  10:48.0   Houston  Golden State
#
#                                               events  is_home_event  \
# 0  Jump ball: C. Capela vs. Z. Pachulia (R. Ander...              0
# 1                 T. Ariza makes 2-pt shot from 1 ft              0
# 2  K. Durant makes 2-pt shot at rim (assist by Z....              1
# 3                C. Capela makes 2-pt shot from 3 ft              0
# 4  S. Curry makes 2-pt shot from 12 ft (assist by...              1
#
#    away_score  home_score  score_diff  t_elapsed
# 0           2           0          -2          0
# 1           2           0          -2         22
# 2           2           2           0         47
# 3           4           2          -2         59
# 4           4           4           0         72

# %%
box1_req = requests.get("https://www.basketball-reference.com/boxscores/201710170CLE.html")
box1_page = box1_req.text
box1_soup = BeautifulSoup(box1_page, 'html.parser')

# %%
box1_tables = box1_soup.find('div', id="all_box_bos_basic")

# %%
box1_rows = box1_tables.find('table', 'stats_table', 'sortable').find('tbody').find_all('tr')

# %%
players = []
for row in box1_rows:
    players.append(row.find('th').get_text())
players.remove('Reserves')

# %%
players
# Out:
# ['Jaylen Brown',
#  'Kyrie Irving',
#  'Jayson Tatum',
#  'Al Horford',
#  'Gordon Hayward',
#  'Marcus Smart',
#  'Terry Rozier',
#  'Aron Baynes',
#  'Semi Ojeleye',
#  'Shane Larkin',
#  'Abdel Nader',
#  'Daniel Theis']

# %%
game1_dict = {}
count_start = 0
for player in players:
    if count_start < 5:
        game1_dict[player] = [1]
        count_start += 1
    else:
        game1_dict[player] = [0]

# %%
game1_dict
# Out:
# {'Abdel Nader': [0],
#  'Al Horford': [1],
#  'Aron Baynes': [0],
#  'Daniel Theis': [0],
#  'Gordon Hayward': [1],
#  'Jaylen Brown': [1],
#  'Jayson Tatum': [1],
#  'Kyrie Irving': [1],
#  'Marcus Smart': [0],
#  'Semi Ojeleye': [0],
#  'Shane Larkin': [0],
#  'Terry Rozier': [0]}

# %%
game1_req = requests.get("https://www.basketball-reference.com/boxscores/pbp/201710200PHI.html")
game1_page = game1_req.text
game1_soup = BeautifulSoup(game1_page, 'html.parser')

# %%
gmae1_table = game1_soup.find('table', 'stats_table', 'sortable')

# %%
game1_rows = gmae1_table.find_all('tr')

# %%
len(game1_rows)
# Out:
# 520

# %%
# Set up variables:
game1_dict['time_left'] = []

game1_dict['home_make'] = []
game1_dict['home_assist'] = []
game1_dict['home_fouled'] = []


game1_dict['road_score'] = []
game1_dict['home_score'] = []
game1_dict['score_diff'] = []

# %%
quarter_str = ['Start of 1st', 'Start of 2nd', 'Start of 3rd', 'Start of 4th']
quarter_mul = [1, 2, 3, 4]
for row in game1_rows:
    if len(row.find_all('td')) == 6:
        row_info = row.find_all('td')
        
        # Calculate Time Left
        time_str = row_info[0].get_text().split(':')
        time_min = float(time_str[0])
        time_s = float(time_str[1])
        time_adj = time_min*mul + time_s
        game1_dict['time_left'].append(1 - time_adj/(48*60))
        
        # Road Team Possesion
        home_possesion = row_info[1].get_text()
        if home_possesion != '\xa0':
            if 'makes' in home_possesion:
                game1_dict['home_make'].append(1)
                if 'assist' in home_possesion:
                    game1_dict['home_assist'].append(1)
                game1_dict['home_fouled'].append(0)
            else:
                game1_dict['home_make'].append(0)
                game1_dict['home_assist'].append(0)
                if 'Shooting foul' in home_possesion:
                    game1_dict['home_fouled'].append(1)
            
        # Score
        score_str = row_info[3].split('-')
        game1_dict['road_score'].append(int(score_str[0]))
        game1_dict['home_score'].append(int(score_str[1]))
        game1_dict['score_diff'].append(home_score - road_score)
        
        # Home Tram Possesion
        if row_info[5].get_text() != '\xa0':
            
    else:
        for ind in range(len(quarter_str)):
            if quarter_str[ind] in row.get_text():
                mul = quarter_mul[ind]
                break

# %%
game1_rows[4].find_all('td')
# Out:
# [<td>11:40.0</td>,
#  <td> </td>,
#  <td> </td>,
#  <td class=" center">0-0</td>,
#  <td class=""> </td>,
#  <td class=""><a href="/players/c/covinro01.html">R. Covington</a> misses 2-pt shot from 11 ft</td>]

# %%
game1_rows[4].find_all('td')[5].get_text()
# Out:
# 'R. Covington misses 2-pt shot from 11 ft'

# %%
rown = game1_rows[3]
rown.find_all('td')[1].find_all('a')[0].get_text()
# Out:
# 'J. Embiid'
